# %% [markdown]
# # Excel Basics

# %% [markdown]
# 1. Explain the difference between Relative , Absolute and Mixed Cell Referencing.
# You have the following dataset:
#
# - Relative Reference- Changes automatically when copied to another cell. Excel adjusts the row and column based on the new location.
# - Absolute Reference- Does not change when copied. The $ sign locks both the row and the column.
# - Mixed Reference- Only one part is locked.
#
# 2. Write a formula to calculate the total sales of Car and Bicyle only only.
#
# - Formula to Calculate Total Sales of Car and Bicycle-
#
# Lets Suppose Price of Car is mentioned in B2 Column and, price of bicycle is mentioned in B3 than we will apply the formula =SUM(B2, B3) and the answer will be 510500.
#
# 3. Using the data below, write a formula to calculate the average sales of items priced above 100 but less than
# 300:
#
# - There ar only two values whose price values are meeting the criteria 150 and 250, and there sales value are 1200 and 1500, so lets consider the that sales cloumns is C, and we are assuming the  value 1200 is in C3 Cell and other one is in C4 Cell and if we will apply the formula =average(C3:C4) thna the answer would be 1350.
#
# 4. Count how many customer names are recorded.
#
# - Total numbe of custome are 50 by applying the formula counta
#
# 5. Calculate the Total Sales for each row using a formula.
#
# - We can use the formaula =product(cell1,cell2) and it will give the total sales of the product fo each row.
#
# 6. Calculate the total sales of Notebooks in the North region only.
#
# - The tot la sales of north region is 2900 by applying sum function.
#
# 7. Create a column chart showing total sales by product.
#
# - Column Chart
#
# 8. Insert a line chart showing daily sales trend.
#
# - Line Chart
